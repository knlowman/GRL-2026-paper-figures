# %% [markdown]
# Plotting global OHC anomalies and global-mean SST anomalies over time for 45˚ latitude-bounded 70-yr ramp experiments.

# %%
# %run /home/Kiera.Lowman/Kd-sensitivity-analysis/notebooks/read_and_calculate.ipynb # to get selecting_basins function
# %run /home/Kiera.Lowman/Kd-sensitivity-analysis/notebooks/plotting_functions.ipynb
# %run /home/Kiera.Lowman/Kd-sensitivity-analysis/notebooks/compute_ensemble_means.ipynb
# %run /home/Kiera.Lowman/Kd-sensitivity-analysis/notebooks/time_series_plotting.ipynb

# %%
profiles = ['surf','therm','mid','bot']
prof_strings = ["Surf","Therm","Mid","Bot"]

power_inputs = ['0.1TW', '0.2TW', '0.3TW']
power_var_suff = ['0p1TW', '0p2TW', '0p3TW']
power_strings = ['0.1 TW', '0.2 TW', '0.3 TW']

p10_power_inputs = ['0.019TW','0.036TW']
p10_power_var_suff = ['0p019TW','0p036TW']
p10_power_strings = ['0.019 TW','0.036 TW']

scalar_pp_type = 'ts-annual'
scalar_vars = ["thetaoga","sst_global"]
scalar_diag_file = 'ocean_scalar_monthly'

ramp_scalar_ts_dir = "/home/Kiera.Lowman/Python_figures/45deg_70yr_time_series/"

# %% [markdown]
# # Reading data

# %% [markdown]
# ## Data for the select SURF and THERM experiments

# %%
time_chunk = 25

start = 1
end = 200

for idx, prof in enumerate(profiles[0:2]):
    get_ens_diff_and_means('const',time_chunk,start,end,
                           scalar_vars,
                           pp_type=scalar_pp_type,diag_file=scalar_diag_file,
                           profiles=[prof],
                           power_inputs=[p10_power_inputs[idx]],power_var_suff=[p10_power_var_suff[idx]],
                           lat_bound=45,ramp_exp=True,
                           num_ens_mem=6,omit_mem1=True,
                           verbose=True)
    
    ds_name = f"const_{prof}_{p10_power_var_suff[idx]}_{start}_{end}"
    myVars[ds_name]["OHC"] = calc_OHC_anom(myVars[ds_name].thetaoga)
    diff_ds_name = f"{ds_name}_diff"
    myVars[diff_ds_name]["OHC"] = calc_OHC_anom(myVars[diff_ds_name].thetaoga)

    arr_name = f"const_{prof}_{p10_power_var_suff[idx]}_{start}_{end}_diff_mem_list"
    for ens_idx in range(5):
        myVars[arr_name][ens_idx]["OHC"] = calc_OHC_anom(myVars[arr_name][ens_idx]["thetaoga"])
# Out:
# ['thetaoga', 'sst_global']
# const_ctrl_1_200, const_ctrl_1_200_mem_list done
# surf 0.019TW experiments
# const_surf_0p019TW_1_200 done
# const_surf_0p019TW_1_200_mem_list done
# const_surf_0p019TW_1_200_diff_mem_list
# const_surf_0p019TW_1_200_diff
# ['thetaoga', 'sst_global']
# const_ctrl_1_200, const_ctrl_1_200_mem_list done
# therm 0.036TW experiments
# const_therm_0p036TW_1_200 done
# const_therm_0p036TW_1_200_mem_list done
# const_therm_0p036TW_1_200_diff_mem_list
# const_therm_0p036TW_1_200_diff

# %% [markdown]
# ## Data for standard power inputs

# %%
time_chunk = 25

start = 1
end = 200

get_ens_diff_and_means('const+doub',time_chunk,start,end,
                       scalar_vars,
                       pp_type=scalar_pp_type,diag_file=scalar_diag_file,
                       lat_bound=45,ramp_exp=True,
                       num_ens_mem=6,omit_mem1=True,
                       verbose=True)
# Out:
# ['thetaoga', 'sst_global']
# const_ctrl_1_200, const_ctrl_1_200_mem_list done
# doub_ctrl_1_200, doub_ctrl_1_200_mem_list done
# doub_ctrl_1_200_diff_mem_list
# doub_ctrl_1_200_diff
# surf 0.1TW experiments
# const_surf_0p1TW_1_200 done
# const_surf_0p1TW_1_200_mem_list done
# doub_surf_0p1TW_1_200 done
# doub_surf_0p1TW_1_200_mem_list done
# const_surf_0p1TW_1_200_diff_mem_list
# const_surf_0p1TW_1_200_diff
# doub_surf_0p1TW_1_200_diff_const_ctrl_mem_list
# doub_surf_0p1TW_1_200_diff_const_ctrl
# doub_surf_0p1TW_1_200_diff_1860_mem_list
# doub_surf_0p1TW_1_200_diff_1860
# doub_surf_0p1TW_1_200_diff_2xctrl_mem_list
# doub_surf_0p1TW_1_200_diff_2xctrl
# surf 0.2TW experiments
# const_surf_0p2TW_1_200 done
# const_surf_0p2TW_1_200_mem_list done
# doub_surf_0p2TW_1_200 done
# doub_surf_0p2TW_1_200_mem_list done
# const_surf_0p2TW_1_200_diff_mem_list
# const_surf_0p2TW_1_200_diff
# doub_surf_0p2TW_1_200_diff_const_ctrl_mem_list
# doub_surf_0p2TW_1_200_diff_const_ctrl
# doub_surf_0p2TW_1_200_diff_1860_mem_list
# doub_surf_0p2TW_1_200_diff_1860
# doub_surf_0p2TW_1_200_diff_2xctrl_mem_list
# doub_surf_0p2TW_1_200_diff_2xctrl
# surf 0.3TW experiments
# const_surf_0p3TW_1_200 done
# const_surf_0p3TW_1_200_mem_list done
# doub_surf_0p3TW_1_200 done
# doub_surf_0p3TW_1_200_mem_list done
# const_surf_0p3TW_1_200_diff_mem_list
# const_surf_0p3TW_1_200_diff
# doub_surf_0p3TW_1_200_diff_const_ctrl_mem_list
# doub_surf_0p3TW_1_200_diff_const_ctrl
# doub_surf_0p3TW_1_200_diff_1860_mem_list
# doub_surf_0p3TW_1_200_diff_1860
# doub_surf_0p3TW_1_200_diff_2xctrl_mem_list
# doub_surf_0p3TW_1_200_diff_2xctrl
# therm 0.1TW experiments
# const_therm_0p1TW_1_200 done
# const_therm_0p1TW_1_200_mem_list done
# doub_therm_0p1TW_1_200 done
# doub_therm_0p1TW_1_200_mem_list done
# const_therm_0p1TW_1_200_diff_mem_list
# const_therm_0p1TW_1_200_diff
# doub_therm_0p1TW_1_200_diff_const_ctrl_mem_list
# doub_therm_0p1TW_1_200_diff_const_ctrl
# doub_therm_0p1TW_1_200_diff_1860_mem_list
# doub_therm_0p1TW_1_200_diff_1860
# doub_therm_0p1TW_1_200_diff_2xctrl_mem_list
# doub_therm_0p1TW_1_200_diff_2xctrl
# therm 0.2TW experiments
# const_therm_0p2TW_1_200 done
# const_therm_0p2TW_1_200_mem_list done
# doub_therm_0p2TW_1_200 done
# doub_therm_0p2TW_1_200_mem_list done
# const_therm_0p2TW_1_200_diff_mem_list
# const_therm_0p2TW_1_200_diff
# doub_therm_0p2TW_1_200_diff_const_ctrl_mem_list
# doub_therm_0p2TW_1_200_diff_const_ctrl
# doub_therm_0p2TW_1_200_diff_1860_mem_list
# doub_therm_0p2TW_1_200_diff_1860
# doub_therm_0p2TW_1_200_diff_2xctrl_mem_list
# doub_therm_0p2TW_1_200_diff_2xctrl
# therm 0.3TW experiments
# const_therm_0p3TW_1_200 done
# const_therm_0p3TW_1_200_mem_list done
# doub_therm_0p3TW_1_200 done
# doub_therm_0p3TW_1_200_mem_list done
# const_therm_0p3TW_1_200_diff_mem_list
# const_therm_0p3TW_1_200_diff
# doub_therm_0p3TW_1_200_diff_const_ctrl_mem_list
# doub_therm_0p3TW_1_200_diff_const_ctrl
# doub_therm_0p3TW_1_200_diff_1860_mem_list
# doub_therm_0p3TW_1_200_diff_1860
# doub_therm_0p3TW_1_200_diff_2xctrl_mem_list
# doub_therm_0p3TW_1_200_diff_2xctrl
# mid 0.1TW experiments
# const_mid_0p1TW_1_200 done
# const_mid_0p1TW_1_200_mem_list done
# doub_mid_0p1TW_1_200 done
# doub_mid_0p1TW_1_200_mem_list done
# const_mid_0p1TW_1_200_diff_mem_list
# const_mid_0p1TW_1_200_diff
# doub_mid_0p1TW_1_200_diff_const_ctrl_mem_list
# doub_mid_0p1TW_1_200_diff_const_ctrl
# doub_mid_0p1TW_1_200_diff_1860_mem_list
# doub_mid_0p1TW_1_200_diff_1860
# doub_mid_0p1TW_1_200_diff_2xctrl_mem_list
# doub_mid_0p1TW_1_200_diff_2xctrl
# mid 0.2TW experiments
# const_mid_0p2TW_1_200 done
# const_mid_0p2TW_1_200_mem_list done
# doub_mid_0p2TW_1_200 done
# doub_mid_0p2TW_1_200_mem_list done
# const_mid_0p2TW_1_200_diff_mem_list
# const_mid_0p2TW_1_200_diff
# doub_mid_0p2TW_1_200_diff_const_ctrl_mem_list
# doub_mid_0p2TW_1_200_diff_const_ctrl
# doub_mid_0p2TW_1_200_diff_1860_mem_list
# doub_mid_0p2TW_1_200_diff_1860
# doub_mid_0p2TW_1_200_diff_2xctrl_mem_list
# doub_mid_0p2TW_1_200_diff_2xctrl
# mid 0.3TW experiments
# const_mid_0p3TW_1_200 done
# const_mid_0p3TW_1_200_mem_list done
# doub_mid_0p3TW_1_200 done
# doub_mid_0p3TW_1_200_mem_list done
# const_mid_0p3TW_1_200_diff_mem_list
# const_mid_0p3TW_1_200_diff
# doub_mid_0p3TW_1_200_diff_const_ctrl_mem_list
# doub_mid_0p3TW_1_200_diff_const_ctrl
# doub_mid_0p3TW_1_200_diff_1860_mem_list
# doub_mid_0p3TW_1_200_diff_1860
# doub_mid_0p3TW_1_200_diff_2xctrl_mem_list
# doub_mid_0p3TW_1_200_diff_2xctrl
# bot 0.1TW experiments
# const_bot_0p1TW_1_200 done
# const_bot_0p1TW_1_200_mem_list done
# doub_bot_0p1TW_1_200 done
# doub_bot_0p1TW_1_200_mem_list done
# const_bot_0p1TW_1_200_diff_mem_list
# const_bot_0p1TW_1_200_diff
# doub_bot_0p1TW_1_200_diff_const_ctrl_mem_list
# doub_bot_0p1TW_1_200_diff_const_ctrl
# doub_bot_0p1TW_1_200_diff_1860_mem_list
# doub_bot_0p1TW_1_200_diff_1860
# doub_bot_0p1TW_1_200_diff_2xctrl_mem_list
# doub_bot_0p1TW_1_200_diff_2xctrl
# bot 0.2TW experiments
# const_bot_0p2TW_1_200 done
# const_bot_0p2TW_1_200_mem_list done
# doub_bot_0p2TW_1_200 done
# doub_bot_0p2TW_1_200_mem_list done
# const_bot_0p2TW_1_200_diff_mem_list
# const_bot_0p2TW_1_200_diff
# doub_bot_0p2TW_1_200_diff_const_ctrl_mem_list
# doub_bot_0p2TW_1_200_diff_const_ctrl
# doub_bot_0p2TW_1_200_diff_1860_mem_list
# doub_bot_0p2TW_1_200_diff_1860
# doub_bot_0p2TW_1_200_diff_2xctrl_mem_list
# doub_bot_0p2TW_1_200_diff_2xctrl
# bot 0.3TW experiments
# const_bot_0p3TW_1_200 done
# const_bot_0p3TW_1_200_mem_list done
# doub_bot_0p3TW_1_200 done
# doub_bot_0p3TW_1_200_mem_list done
# const_bot_0p3TW_1_200_diff_mem_list
# const_bot_0p3TW_1_200_diff
# doub_bot_0p3TW_1_200_diff_const_ctrl_mem_list
# doub_bot_0p3TW_1_200_diff_const_ctrl
# doub_bot_0p3TW_1_200_diff_1860_mem_list
# doub_bot_0p3TW_1_200_diff_1860
# doub_bot_0p3TW_1_200_diff_2xctrl_mem_list
# doub_bot_0p3TW_1_200_diff_2xctrl

# %% [markdown]
# ### Calculate OHC for ensemble members

# %%
# members: calculate OHC
for co2_scen in ['const','doub']:
    arr_name = f"{co2_scen}_ctrl_{start}_{end}_mem_list"
    for ens_idx in range(5):
        myVars[arr_name][ens_idx]["OHC"] = calc_OHC_anom(myVars[arr_name][ens_idx]["thetaoga"])
        
for co2_scen in ['const','doub']:
    for prof in profiles:
        for power in power_var_suff:
            arr_name = f"{co2_scen}_{prof}_{power}_{start}_{end}_mem_list"
            for ens_idx in range(5):
                myVars[arr_name][ens_idx]["OHC"] = calc_OHC_anom(myVars[arr_name][ens_idx]["thetaoga"])

# %%
# members: calculate OHC differences
arr_name = f"doub_ctrl_{start}_{end}_diff_mem_list"
for ens_idx in range(5):
    myVars[arr_name][ens_idx]["OHC"] = calc_OHC_anom(myVars[arr_name][ens_idx]["thetaoga"])

for diff_type in ['const','1860','2xctrl','const_ctrl']:
    for prof in profiles:
        for power in power_var_suff:
            if diff_type == 'const':
                arr_name = f"const_{prof}_{power}_{start}_{end}_diff_mem_list"
            else:
                arr_name = f"doub_{prof}_{power}_{start}_{end}_diff_{diff_type}_mem_list"
            for ens_idx in range(5):
                myVars[arr_name][ens_idx]["OHC"] = calc_OHC_anom(myVars[arr_name][ens_idx]["thetaoga"])

# %% [markdown]
# ### Calculate OHC for ensemble mean

# %%
# mean: calculate OHC
for co2_scen in ['const','doub']:
    ds_name = f"{co2_scen}_ctrl_{start}_{end}"
    myVars[ds_name]["OHC"] = calc_OHC_anom(myVars[ds_name].thetaoga)
    for prof in profiles:
        for power in power_var_suff:
            ds_name = f"{co2_scen}_{prof}_{power}_{start}_{end}"
            myVars[ds_name]["OHC"] = calc_OHC_anom(myVars[ds_name].thetaoga)

# %%
# mean: calculate OHC differences
for co2_scen in ['const','doub']:
    if co2_scen == 'doub':
        ds_name = f"{co2_scen}_ctrl_{start}_{end}_diff"
        myVars[ds_name]["OHC"] = calc_OHC_anom(myVars[ds_name].thetaoga)
    for prof in profiles:
        for power in power_var_suff:
            if co2_scen == 'doub':
                for diff_suff in ['const_ctrl','1860','2xctrl']:
                    ds_name = f"{co2_scen}_{prof}_{power}_{start}_{end}_diff_{diff_suff}"
                    myVars[ds_name]["OHC"] = calc_OHC_anom(myVars[ds_name].thetaoga)
            else:
                ds_name = f"{co2_scen}_{prof}_{power}_{start}_{end}_diff"
                myVars[ds_name]["OHC"] = calc_OHC_anom(myVars[ds_name].thetaoga)

# %% [markdown]
# # OHC plots

# %%
start = 1
end = 200

comp_OHC_ystep_list = [200,500,500]
comp_OHC_frac_list = [0.25,0.2,0.2]
comp_OHC_ylims_list = [None,
                       None,
                       [-100,2600]]

tot_OHC_ystep_list = [500,800,800]
tot_OHC_frac_list = [0.2,0.25,0.25]
tot_OHC_ylims_list = [None,
                      None,#[-200,4300],
                      None]

# %%
plot_ts_mixing_diff('doub',ramp_scalar_ts_dir,start,end,fig_pref="45deg_70yr",anom_var='OHC',
                    roll_mean = False, ystep_list = comp_OHC_ystep_list, ymin_frac_list = comp_OHC_frac_list, ylims_list = comp_OHC_ylims_list,
                     leg_loc = 'upper left',
                     leg_ncols = 1,
                   plot_ens_env=True)

# %%
plot_ts_lin_pow_diff('const',ramp_scalar_ts_dir,start,end,fig_pref="45deg_70yr",anom_var='OHC',
                     roll_mean = False, ystep=500,
                    plot_ens_env=True)

# %%
plot_ts_rad_pow_diff('doub',ramp_scalar_ts_dir,start,end,fig_pref="45deg_70yr",anom_var='OHC',
                    roll_mean = False, ystep=500,
                     leg_loc = 'upper left',
                     leg_ncols = 1,
                    plot_ens_env=True)

# %%
plot_ts_mix_pow_diff('const',ramp_scalar_ts_dir,start,end,fig_pref="45deg_70yr",anom_var='OHC',
                     ystep=500, #ylimits=(-100,2600),
                     # profiles=['mid','bot'],omit_ctrl=True,
                     #   power_var_suff = ['0p2TW', '0p3TW'], 
                     #   power_strings = ['0.2 TW', '0.3 TW'],
                     roll_mean = False,
                    plot_ens_env=True)

# %%
plot_lin_ts_diff('doub',ramp_scalar_ts_dir,start,end,fig_pref="45deg_70yr",anom_var='OHC',
                 ystep_list = tot_OHC_ystep_list, ymin_frac_list = tot_OHC_frac_list, ylims_list = tot_OHC_ylims_list,
                     roll_mean = False,
                 plot_ens_env=True
                )

# %% [markdown]
# ## Percent differences in mixing OHC between CO2 scenarios

# %%
print("const and doub 0.1 TW OHC anomalies at yr 200")
for prof in profiles:
    const_ds = f"const_{prof}_0p1TW_1_200_diff"
    doub_ds = f"doub_{prof}_0p1TW_1_200_diff_2xctrl"
    const_val = myVars[const_ds].OHC.isel(time=-1).values
    doub_val = myVars[doub_ds].OHC.isel(time=-1).values
    per_diff = abs(100*(const_val-doub_val)/((const_val+doub_val)/2))
    raw_diff = doub_val - const_val
    print(f"{prof}: {const_val:.4g}\t{doub_val:.4g}\t per_diff: {per_diff:.4g}")
    # print(f"raw difference: {raw_diff:.4g}\n")

print("const and doub 0.2 TW OHC anomalies at yr 200")
for prof in profiles:
    const_ds = f"const_{prof}_0p2TW_1_200_diff"
    doub_ds = f"doub_{prof}_0p2TW_1_200_diff_2xctrl"
    const_val = myVars[const_ds].OHC.isel(time=-1).values
    doub_val = myVars[doub_ds].OHC.isel(time=-1).values
    per_diff = abs(100*(const_val-doub_val)/((const_val+doub_val)/2))
    raw_diff = doub_val - const_val
    print(f"{prof}: {const_val:.4g}\t{doub_val:.4g}\t per_diff: {per_diff:.4g}")
    # print(f"raw difference: {raw_diff:.4g}\n")

print("const and doub 0.3 TW OHC anomalies at yr 200")
for prof in profiles:
    const_ds = f"const_{prof}_0p3TW_1_200_diff"
    doub_ds = f"doub_{prof}_0p3TW_1_200_diff_2xctrl"
    const_val = myVars[const_ds].OHC.isel(time=-1).values
    doub_val = myVars[doub_ds].OHC.isel(time=-1).values
    per_diff = abs(100*(const_val-doub_val)/((const_val+doub_val)/2))
    raw_diff = doub_val - const_val
    print(f"{prof}: {const_val:.4g}\t{doub_val:.4g}\t per_diff: {per_diff:.4g}")
    # print(f"raw difference: {raw_diff:.4g}\n")
# Out:
# const and doub 0.1 TW OHC anomalies at yr 200
# surf: 877.4	859.6	 per_diff: 2.044
# therm: 960.4	739.1	 per_diff: 26.05
# mid: 37.75	25.6	 per_diff: 38.36
# bot: 31.88	-26.54	 per_diff: 2186
# const and doub 0.2 TW OHC anomalies at yr 200
# surf: 1644	1611	 per_diff: 2.023
# therm: 1808	1427	 per_diff: 23.56
# mid: 123.5	49.87	 per_diff: 84.93
# bot: 42.04	-21.66	 per_diff: 625.4
# const and doub 0.3 TW OHC anomalies at yr 200
# surf: 2300	2293	 per_diff: 0.3087
# therm: 2531	2119	 per_diff: 17.69
# mid: 220.3	96.76	 per_diff: 77.93
# bot: 51.53	-17.22	 per_diff: 400.7

# %%
date_yr70 = cftime.DatetimeNoLeap(70, 7, 2, 12, 0, 0, 0, has_year_zero=True)

print("const and doub 0.1 TW OHC anomalies at yr 70")
for prof in profiles:
    const_ds = f"const_{prof}_0p1TW_1_200_diff"
    doub_ds = f"doub_{prof}_0p1TW_1_200_diff_2xctrl"
    const_val = myVars[const_ds].OHC.sel(time=date_yr70).values
    doub_val = myVars[doub_ds].OHC.sel(time=date_yr70).values
    per_diff = abs(100*(const_val-doub_val)/((const_val+doub_val)/2))
    raw_diff = doub_val - const_val
    print(f"{prof}: {const_val:.4g}\t{doub_val:.4g}\t per_diff: {per_diff:.4g}")
    # print(f"raw difference: {raw_diff:.4g}\n")

print("const and doub 0.2 TW OHC anomalies at yr 70")
for prof in profiles:
    const_ds = f"const_{prof}_0p2TW_1_200_diff"
    doub_ds = f"doub_{prof}_0p2TW_1_200_diff_2xctrl"
    const_val = myVars[const_ds].OHC.sel(time=date_yr70).values
    doub_val = myVars[doub_ds].OHC.sel(time=date_yr70).values
    per_diff = abs(100*(const_val-doub_val)/((const_val+doub_val)/2))
    raw_diff = doub_val - const_val
    print(f"{prof}: {const_val:.4g}\t{doub_val:.4g}\t per_diff: {per_diff:.4g}")
    # print(f"raw difference: {raw_diff:.4g}\n")

print("const and doub 0.3 TW OHC anomalies at yr 70")
for prof in profiles:
    const_ds = f"const_{prof}_0p3TW_1_200_diff"
    doub_ds = f"doub_{prof}_0p3TW_1_200_diff_2xctrl"
    const_val = myVars[const_ds].OHC.sel(time=date_yr70).values
    doub_val = myVars[doub_ds].OHC.sel(time=date_yr70).values
    per_diff = abs(100*(const_val-doub_val)/((const_val+doub_val)/2))
    raw_diff = doub_val - const_val
    print(f"{prof}: {const_val:.4g}\t{doub_val:.4g}\t per_diff: {per_diff:.4g}")
    # print(f"raw difference: {raw_diff:.4g}\n")
# Out:
# const and doub 0.1 TW OHC anomalies at yr 70
# surf: 363	365.5	 per_diff: 0.6776
# therm: 179	142	 per_diff: 23.05
# mid: 8.828	0.7779	 per_diff: 167.6
# bot: -2.281	-6.209	 per_diff: 92.55
# const and doub 0.2 TW OHC anomalies at yr 70
# surf: 666.6	671	 per_diff: 0.6473
# therm: 347.3	314.2	 per_diff: 10.01
# mid: 11.92	11.65	 per_diff: 2.272
# bot: 11.65	3.724	 per_diff: 103.1
# const and doub 0.3 TW OHC anomalies at yr 70
# surf: 943.3	957.5	 per_diff: 1.502
# therm: 538.4	478.7	 per_diff: 11.73
# mid: 21.81	10.08	 per_diff: 73.6
# bot: 20.7	-12.33	 per_diff: 789.4

# %% [markdown]
# ## Comparing radiative OHC at 200 yr

# %%
print("Radiative OHC anomalies at yr 200")
print(f"1pct2xCO2 control: {doub_ctrl_1_200_diff.OHC.isel(time=-1).values:5g} ZJ")

doub_vals = []

for prof in profiles:
    doub_val_strings = []
    for power in power_var_suff:
        doub_ds = f"doub_{prof}_{power}_1_200_diff_1860"
        doub_vals.append(myVars[doub_ds].OHC.isel(time=-1).values)
        doub_val_strings.append(f"{doub_vals[-1]:.5g}")
    print(doub_val_strings)
    
print(np.min(doub_vals))
print(np.max(doub_vals))
# Out:
# Radiative OHC anomalies at yr 200
# 1pct2xCO2 control: 2470.18 ZJ
# ['2452.4', '2437.3', '2463.1']
# ['2248.8', '2089.2', '2058.8']
# ['2458', '2396.6', '2346.6']
# ['2411.8', '2406.5', '2401.4']
# 2058.7668991758046
# 2463.0901578074745

# %% [markdown]
# ## Required energy for mixing OHC = 10% radiative OHC

# %% [markdown]
# ### yr 70

# %%
date_yr70 = cftime.DatetimeNoLeap(70, 7, 2, 12, 0, 0, 0, has_year_zero=True)

for idx, power in enumerate(power_var_suff):
    print(f"Constant CO2 ramp {power_strings[idx]} 70-yr response")
    for prof in profiles:
        ds_name = f"const_{prof}_{power}_1_200_diff"
        OHC_val = myVars[ds_name].OHC.sel(time=date_yr70).values
        print(f"{prof}: {OHC_val:.4e} ZJ")
    print("")

print("\n1pct2xCO2 control 70-yr response")
dt_co2 = doub_ctrl_1_200_diff.OHC.sel(time=date_yr70).values
print(f"{dt_co2:.4e} ZJ")

print("\nRequired energy input for mixing response equal to 100% or 10% of CO2 response")

power_floats = np.array([0.1, 0.2, 0.3])
for idx, power in enumerate(power_var_suff):
    print(f"\nEstimates from {power_strings[idx]} ramp experiments:")
    for prof in profiles:
        mix_resp_name = f"const_{prof}_{power}_1_200_diff"
        dt_mix = myVars[mix_resp_name].OHC.sel(time=date_yr70).values
        
        roc = dt_mix/power_floats[idx]
        req_energy = dt_co2/roc
        p10_req_energy = dt_co2*0.1/roc
        
        print(f"Rate of change: {roc:4e} ZJ per TW; \t{prof}:\t {req_energy:.3f} TW; {p10_req_energy:.4f} TW")
# Out:
# Constant CO2 ramp 0.1 TW 70-yr response
# surf: 3.6301e+02 ZJ
# therm: 1.7903e+02 ZJ
# mid: 8.8283e+00 ZJ
# bot: -2.2805e+00 ZJ
#
# Constant CO2 ramp 0.2 TW 70-yr response
# surf: 6.6665e+02 ZJ
# therm: 3.4734e+02 ZJ
# mid: 1.1916e+01 ZJ
# bot: 1.1651e+01 ZJ
#
# Constant CO2 ramp 0.3 TW 70-yr response
# surf: 9.4325e+02 ZJ
# therm: 5.3839e+02 ZJ
# mid: 2.1814e+01 ZJ
# bot: 2.0697e+01 ZJ
#
#
# 1pct2xCO2 control 70-yr response
# 6.4132e+02 ZJ
#
# Required energy input for mixing response equal to 100% or 10% of CO2 response
#
# Estimates from 0.1 TW ramp experiments:
# Rate of change: 3.630144e+03 ZJ per TW; 	surf:	 0.177 TW; 0.0177 TW
# Rate of change: 1.790252e+03 ZJ per TW; 	therm:	 0.358 TW; 0.0358 TW
# Rate of change: 8.828298e+01 ZJ per TW; 	mid:	 7.264 TW; 0.7264 TW
# Rate of change: -2.280515e+01 ZJ per TW; 	bot:	 -28.122 TW; -2.8122 TW
#
# Estimates from 0.2 TW ramp experiments:
# Rate of change: 3.333230e+03 ZJ per TW; 	surf:	 0.192 TW; 0.0192 TW
# Rate of change: 1.736722e+03 ZJ per TW; 	therm:	 0.369 TW; 0.0369 TW
# Rate of change: 5.957886e+01 ZJ per TW; 	mid:	 10.764 TW; 1.0764 TW
# Rate of change: 5.825621e+01 ZJ per TW; 	bot:	 11.009 TW; 1.1009 TW
#
# Estimates from 0.3 TW ramp experiments:
# Rate of change: 3.144178e+03 ZJ per TW; 	surf:	 0.204 TW; 0.0204 TW
# Rate of change: 1.794617e+03 ZJ per TW; 	therm:	 0.357 TW; 0.0357 TW
# Rate of change: 7.271240e+01 ZJ per TW; 	mid:	 8.820 TW; 0.8820 TW
# Rate of change: 6.898935e+01 ZJ per TW; 	bot:	 9.296 TW; 0.9296 TW

# %%
date_yr70 = cftime.DatetimeNoLeap(70, 7, 2, 12, 0, 0, 0, has_year_zero=True)

for idx, power in enumerate(power_var_suff):
    print(f"1pct2xCO2 ramp {power_strings[idx]} 70-yr response")
    for prof in profiles:
        ds_name = f"doub_{prof}_{power}_1_200_diff_2xctrl"
        OHC_val = myVars[ds_name].OHC.sel(time=date_yr70).values
        print(f"{prof}: {OHC_val:.4e} ZJ")
    print("")

print("\n1pct2xCO2 control 70-yr response")
dt_co2 = doub_ctrl_1_200_diff.OHC.sel(time=date_yr70).values
print(f"{dt_co2:.4e} ZJ")

print("\nRequired energy input for mixing response equal to 100% or 10% of CO2 response")

power_floats = np.array([0.1, 0.2, 0.3])
for idx, power in enumerate(power_var_suff):
    print(f"\nEstimates from {power_strings[idx]} ramp experiments:")
    for prof in profiles:
        mix_resp_name = f"doub_{prof}_{power}_1_200_diff_2xctrl"
        dt_mix = myVars[mix_resp_name].OHC.sel(time=date_yr70).values
        
        roc = dt_mix/power_floats[idx]
        req_energy = dt_co2/roc
        p10_req_energy = dt_co2*0.1/roc
        
        print(f"Rate of change: {roc:4e} ZJ per TW; \t{prof}:\t {req_energy:.3f} TW; {p10_req_energy:.4f} TW")
# Out:
# 1pct2xCO2 ramp 0.1 TW 70-yr response
# surf: 3.6548e+02 ZJ
# therm: 1.4202e+02 ZJ
# mid: 7.7790e-01 ZJ
# bot: -6.2092e+00 ZJ
#
# 1pct2xCO2 ramp 0.2 TW 70-yr response
# surf: 6.7098e+02 ZJ
# therm: 3.1423e+02 ZJ
# mid: 1.1648e+01 ZJ
# bot: 3.7244e+00 ZJ
#
# 1pct2xCO2 ramp 0.3 TW 70-yr response
# surf: 9.5753e+02 ZJ
# therm: 4.7872e+02 ZJ
# mid: 1.0077e+01 ZJ
# bot: -1.2330e+01 ZJ
#
#
# 1pct2xCO2 control 70-yr response
# 6.4132e+02 ZJ
#
# Required energy input for mixing response equal to 100% or 10% of CO2 response
#
# Estimates from 0.1 TW ramp experiments:
# Rate of change: 3.654827e+03 ZJ per TW; 	surf:	 0.175 TW; 0.0175 TW
# Rate of change: 1.420214e+03 ZJ per TW; 	therm:	 0.452 TW; 0.0452 TW
# Rate of change: 7.779005e+00 ZJ per TW; 	mid:	 82.442 TW; 8.2442 TW
# Rate of change: -6.209181e+01 ZJ per TW; 	bot:	 -10.329 TW; -1.0329 TW
#
# Estimates from 0.2 TW ramp experiments:
# Rate of change: 3.354878e+03 ZJ per TW; 	surf:	 0.191 TW; 0.0191 TW
# Rate of change: 1.571127e+03 ZJ per TW; 	therm:	 0.408 TW; 0.0408 TW
# Rate of change: 5.824069e+01 ZJ per TW; 	mid:	 11.012 TW; 1.1012 TW
# Rate of change: 1.862216e+01 ZJ per TW; 	bot:	 34.439 TW; 3.4439 TW
#
# Estimates from 0.3 TW ramp experiments:
# Rate of change: 3.191765e+03 ZJ per TW; 	surf:	 0.201 TW; 0.0201 TW
# Rate of change: 1.595736e+03 ZJ per TW; 	therm:	 0.402 TW; 0.0402 TW
# Rate of change: 3.359078e+01 ZJ per TW; 	mid:	 19.092 TW; 1.9092 TW
# Rate of change: -4.109923e+01 ZJ per TW; 	bot:	 -15.604 TW; -1.5604 TW

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

# 70-yr requirements
values = [0.019, 0.036, 0.9] # , 0
errors = [0.005, 0.005, 0.3] # , 0
colors = ['b', 'm', 'g'] # , 'r'

fig, ax = plt.subplots(figsize=(6, 3))

# --- Main plot ---
bars = ax.barh(
    prof_strings[0:3],
    values,
    xerr=errors,
    capsize=5,
    color=colors
)

ax.set_xlim(0, 2)
ax.set_xlabel("Required Energy Input (TW)")

# Main annotations
padding = 0.04 * (max(values) + max(errors))
for bar, err in zip(bars, errors):
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    ax.text(
        width + err + padding, y,
        f"{width:g}",
        va="center",
        ha="left",
        fontweight="bold"
    )

# --- Inset: zoom on the first two tiny bars ---
small_idx = [0, 1]

# Create inset axes inside the main axes
axins = inset_axes(
    ax,
    width="60%",     # size of inset
    height="60%",
    loc="lower right",
    borderpad=1.0
)

# Plot ONLY the small bars in the inset
prof_small = [prof_strings[i] for i in small_idx]
vals_small = [values[i] for i in small_idx]
errs_small = [errors[i] for i in small_idx]
cols_small = [colors[i] for i in small_idx]

bars_inset = axins.barh(
    prof_small,
    vals_small,
    xerr=errs_small,
    capsize=4,
    color=cols_small
)

# Zoomed x-limits: a bit beyond (value + error) for the small bars
xmax_small = max(v + e for v, e in zip(vals_small, errs_small))
axins.set_xlim(0, xmax_small * 1.35)

# Make inset labels readable / compact
axins.tick_params(axis="both", labelsize=8)
axins.set_xticklabels([])
axins.set_xlabel("")  # usually cleaner to omit inset xlabel

# Inset annotations (smaller font)
inset_padding = 0.04 * axins.get_xlim()[1]
for bar, err in zip(bars_inset, errs_small):
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    axins.text(
        width + err + inset_padding, y,
        f"{width:.3f}",
        va="center",
        ha="left",
        fontweight="bold",
        fontsize=8
    )

# Draw connectors showing what region is zoomed
mark_inset(ax, axins, loc1=2, loc2=4, fc="none", ec="0.5", lw=1)

plt.savefig(
    "/home/Kiera.Lowman/Python_figures/45deg_70yr_bar_charts/45deg_70yr_OHC_yr70_req_bar_chart.pdf",
    dpi=600,
    bbox_inches="tight"
)
plt.show()

# %% [markdown]
# ## Plot for select power inputs

# %%
plot_ts_diff_select('const',ramp_scalar_ts_dir,start,end,p10_power_var_suff,p10_power_strings,profiles = profiles[0:2],anom_var='OHC',
                    fig_pref="45deg_70yr_10percent",
                    vline_yr=70,
                    roll_mean = False,
                    leg_loc = 'upper left',
                    plot_ens_env=True
                   )

# %% [markdown]
# # SST_global plots

# %%
start = 1
end = 200

comp_sst_ystep_list = [0.1,0.2,0.2]
comp_sst_frac_list = [0.25,0.25,0.25]
comp_sst_ylims_list = [[-0.3,0.2],
                       [-0.45,0.4],
                       [-0.6,0.4]]

tot_sst_ystep_list = [0.2,0.2,0.2]
tot_sst_frac_list = [0.25,0.25,0.25]
tot_sst_ylims_list = [[-0.05,1.3],
                      [-0.05,1.6],
                      [-0.05,1.8]]
